# %%
title = "Supporting RISE"

# %%
tags_list = ['RISE', 'slideshow', 'reveal', 'Jupyter', 'support', 'kofi', 'opensource']

# %%
tags = ', '.join(tags_list)

# !nikola new_post -f ipynb --title="{title}" --tags="{tags}"
# Out:
# /bin/sh: 1: nikola: not found
